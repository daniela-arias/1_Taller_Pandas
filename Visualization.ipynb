# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (13.,7.)})
sns.set_style("whitegrid")

# %%
# !pwd
# Out:
# /Users/danielaarias/Ironhack/1_Taller_Pandas

# %%
df = pd.read_csv("Data/Cleaning_ready.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Type Sex Fatal  Species_new
# 0           0        Boat   F     N  White shark
# 1           1  Unprovoked   F     N       Others
# 2           2     Invalid   M     N       Others
# 3           3  Unprovoked   M     N       Others
# 4           4    Provoked   M     N  Tiger shark

# %%
Specie_new1 = df[df["Species_new"] != 'Others']

# %%
Specie_new1.head()
# Out:
#     Unnamed: 0        Type Sex Fatal  Species_new
# 0            0        Boat   F     N  White shark
# 4            4    Provoked   M     N  Tiger shark
# 6            6  Unprovoked   M     Y  Tiger shark
# 7            7  Unprovoked   M     N  Lemon shark
# 10          10    Provoked   M     N   Grey shark

# %% [markdown]
# # ***¿Están relacionados los tipos de ataques de tiburones con las especies?***

# %%
Specie_new1.groupby(["Species_new"])["Type"].count().plot(kind="bar", color=["pink","coral"]);

# %% [markdown]
# **Puede verse una clara relación en la cantidad de ataques registrados y una especie en particular. Los tiburones blancos son la especie que se tiene registrado con más ataques a humanos. En segundo lugar se encuentra el tiburón tigre.**

# %%
sns.countplot(x="Species_new", data=Specie_new1, palette="magma")
plt.xticks(rotation=45);

# %%
sns.scatterplot(x="Species_new", y="Type", data=Specie_new1, palette="magma", color="coral",sizes=14.8)
plt.xticks(rotation=45);

# %% [markdown]
# **Como puede verse en el gráfico, el tiburón blanco ha estado presente en todos los tipos de ataques que se han registrados, cómo también el tiburón tigre y el tiburón azul. El resto de las especies se encuentran en los diferentes tipos de ataques de manera dispersa.
# El tipo de ataque "No provocado" se ha detectado en todas las especies, por lo que puede considerarse este tipo de ataque un denominador común en todas las especies.**

# %%
sns.countplot(y="Species_new", hue="Type", data = Specie_new1, palette="magma")
plt.xticks(rotation=45);

# %% [markdown]
# # ***¿Están relacionados los tipos de ataques de tiburones con el género de las víctimas?***

# %%
df.groupby(["Sex"])["Type"].count().plot(kind="bar", color=["pink","coral"]);

# %% [markdown]
# **Podemos ver claramente que la cantidad de ataques se centra sobre todo en el sexo masculino.**

# %%
sns.countplot(x="Type", hue="Sex", data = df, palette="magma")
plt.xticks(rotation=45);

# %% [markdown]
# **Los tipos de ataques son en su mayoria "No provocados" y las víctimas son por diferencia Hombres. Los datos reflejan que los ataques a mujeres son bastante menos frecuentes, en cualquier de los tipos de ataques.**
