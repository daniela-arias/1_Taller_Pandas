# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re

# %%
# !pwd
# Out:
# /Users/danielaarias/Ironhack/1_Taller_Pandas

# %%
df = pd.read_csv("Data/attacks.csv",encoding = "ISO-8859-1")

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.head(2)
# Out:
#   Case Number         Date    Year        Type Country        Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating     USA  California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked     USA     Georgia
#
#                          Location  Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely     F  ...
#
#       Species           Investigator or Source                     pdf  \
# 0  White shark                R. Collier, GSAF    2018.06.25-Wolfe.pdf
# 1          NaN  K.McMurray, TrackingSharks.com  2018.06.18-McNeely.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.drop(["Case Number","href formula", "href", "pdf","Case Number.1","Case Number.2","Investigator or Source","Name","original order"], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.head(2)
# Out:
#           Date    Year        Type Country        Area  \
# 0  25-Jun-2018  2018.0     Boating     USA  California
# 1  18-Jun-2018  2018.0  Unprovoked     USA     Georgia
#
#                          Location  Activity Sex  Age  \
# 0     Oceanside, San Diego County  Paddling    F  57
# 1  St. Simon Island, Glynn County  Standing    F  11
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
#
#             Time     Species  Unnamed: 22 Unnamed: 23
# 0          18h00  White shark         NaN         NaN
# 1  14h00  -15h00          NaN         NaN         NaN

# %%
display(df.Date)
# Out:
# 0        25-Jun-2018
# 1        18-Jun-2018
# 2        09-Jun-2018
# 3        08-Jun-2018
# 4        04-Jun-2018
#             ...
# 25718            NaN
# 25719            NaN
# 25720            NaN
# 25721            NaN
# 25722            NaN
# Name: Date, Length: 25723, dtype: object

# %%
df.isna().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
df.dropna(how="all", inplace=True)

# %%
df.isna().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 19427

# %%
df.drop_duplicates()
# Out:
#       Case Number         Date    Year         Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0      Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0   Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0      Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0   Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0     Provoked     MEXICO
# ...           ...          ...     ...          ...        ...
# 6307            0          NaN     NaN  Not defined        NaN
# 6308            0          NaN     NaN  Not defined        NaN
# 6309            0          NaN     NaN  Not defined        NaN
# 8702          NaN          NaN     NaN  Not defined        NaN
# 25722          xx          NaN     NaN  Not defined        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.duplicated().sum()
# Out:
# 19411

# %%
list(df.Type.unique())
# Out:
# ['Boating',
#  'Unprovoked',
#  'Invalid',
#  'Provoked',
#  'Questionable',
#  'Sea Disaster',
#  'Not defined',
#  'Boat',
#  'Boatomg']

# %%
df.Type.fillna("Not defined",inplace=True)

# %%
df['Type'] = df['Type'].str.replace('Boat"Boatomg','Boating')

# %%
list(df.Type.unique())
# Out:
# ['Boating',
#  'Unprovoked',
#  'Invalid',
#  'Provoked',
#  'Questionable',
#  'Sea Disaster',
#  'Not defined',
#  'Boat',
#  'Boatomg']

# %%
df.Type.str.replace("Boatomg","Boating", regex=True) 
#dejo esto como otra opcion, no se me actualizan los replazos de los valores que necesito
# Out:
# 0            Boating
# 1         Unprovoked
# 2            Invalid
# 3         Unprovoked
# 4           Provoked
#             ...
# 25718    Not defined
# 25719    Not defined
# 25720    Not defined
# 25721    Not defined
# 25722    Not defined
# Name: Type, Length: 25723, dtype: object

# %%
df.Type.str.replace("Boat","Boating",regex=True).implace=True
#dejo esto como otra opcion, no se me actualizan los replazos de los valores que necesito

# %%
list(df.Type.unique())
#siguen estando Boat Boatomg, deberian haberse reemplazaso con Boating
# Out:
# ['Boating',
#  'Unprovoked',
#  'Invalid',
#  'Provoked',
#  'Questionable',
#  'Sea Disaster',
#  'Not defined',
#  'Boat',
#  'Boatomg']

# %%
list(df.Country.unique())
# Out:
# ['USA',
#  'AUSTRALIA',
#  'MEXICO',
#  'BRAZIL',
#  'ENGLAND',
#  'SOUTH AFRICA',
#  'THAILAND',
#  'COSTA RICA',
#  'MALDIVES',
#  'BAHAMAS',
#  'NEW CALEDONIA',
#  'ECUADOR',
#  'MALAYSIA',
#  'LIBYA',
#  nan,
#  'CUBA',
#  'MAURITIUS',
#  'NEW ZEALAND',
#  'SPAIN',
#  'SAMOA',
#  'SOLOMON ISLANDS',
#  'JAPAN',
#  'EGYPT',
#  'ST HELENA, British overseas territory',
#  'COMOROS',
#  'REUNION',
#  'FRENCH POLYNESIA',
#  'UNITED KINGDOM',
#  'UNITED ARAB EMIRATES',
#  'PHILIPPINES',
#  'INDONESIA',
#  'CHINA',
#  'COLUMBIA',
#  'CAPE VERDE',
#  'Fiji',
#  'DOMINICAN REPUBLIC',
#  'CAYMAN ISLANDS',
#  'ARUBA',
#  'MOZAMBIQUE',
#  'FIJI',
#  'PUERTO RICO',
#  'ITALY',
#  'ATLANTIC OCEAN',
#  'GREECE',
#  'ST. MARTIN',
#  'FRANCE',
#  'PAPUA NEW GUINEA',
#  'TRINIDAD & TOBAGO',
#  'KIRIBATI',
#  'ISRAEL',
#  'DIEGO GARCIA',
#  'TAIWAN',
#  'JAMAICA',
#  'PALESTINIAN TERRITORIES',
#  'GUAM',
#  'SEYCHELLES',
#  'BELIZE',
#  'NIGERIA',
#  'TONGA',
#  'SCOTLAND',
#  'CANADA',
# ...

# %%
df.head(2)
# Out:
#           Date    Year        Type Country        Area  \
# 0  25-Jun-2018  2018.0     Boating     USA  California
# 1  18-Jun-2018  2018.0  Unprovoked     USA     Georgia
#
#                          Location  Activity Sex  Age  \
# 0     Oceanside, San Diego County  Paddling    F  57
# 1  St. Simon Island, Glynn County  Standing    F  11
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
#
#             Time     Species  Unnamed: 22 Unnamed: 23
# 0          18h00  White shark         NaN         NaN
# 1  14h00  -15h00          NaN         NaN         NaN

# %%
list(df.Species.unique())
#me indica que Species no es un objeto, pero es una columna - no se porque
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-302-f9403c849791> in <module>
# ----> 1 list(df.Species.unique())
#
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Species'

# %%
df.Species.fillna("Unknown", inplace=True)
#me indica que Species no es un objeto, pero es una columna - no se porque
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-305-aedf71aa6c9d> in <module>
# ----> 1 df.Species.fillna("Unknown", inplace=True)
#
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Species'

# %%
list(df.Activity.unique())
# Out:
# ['Paddling',
#  'Standing',
#  'Surfing',
#  'Free diving',
#  'Kite surfing',
#  'Swimming',
#  'Fishing',
#  'Walking',
#  'Feeding sharks',
#  'Boogie boarding',
#  'Scuba diving',
#  'Paddle-skiing',
#  'Body boarding',
#  'Windsurfing',
#  'Stand-Up Paddleboarding',
#  'Wading',
#  'Scuba Diving',
#  'Kayak fishing for sharks',
#  'Cleaning fish',
#  'Snorkeling',
#  'Spearfishing',
#  nan,
#  'Diving',
#  'Fishing / Wading',
#  '2 boats capsized',
#  'Night bathing',
#  'Surfing ',
#  'Kayaking / Fishing',
#  'Kayaking',
#  'Body surfing',
#  'Swimming, poaching abalone',
#  'Canoeing',
#  'SUP',
#  'Skimboarding',
#  'Touching a shark',
#  'Fishing ',
#  'Attempting to lasso a shark',
#  'Photo shoot',
#  'Paddle boarding',
#  'Kakaying',
#  'Washing hands',
#  'Grabbing shark for a selfie',
#  'Kayak fishing',
#  'Tagging sharks',
#  'Surf skiing ',
#  'Surf fishing',
#  'Floating',
#  'Cage Diving',
#  'Surfng',
#  'SUP Foil boarding',
#  'Lobstering',
# ...

# %%
df.sort_values(by="Date").head()
# Out:
#                  Date    Year          Type      Country             Area  \
# 4425   \n1951.12.15.R  1951.0       Invalid   MOZAMBIQUE  Sofala Province
# 1174      10-Jan-2009  2009.0          Boat  NEW ZEALAND     North Island
# 4849      15-Jun-1937  1937.0    Unprovoked          USA            Texas
# 3404      16-Jan-1970  1970.0  Sea Disaster        EGYPT          Red Sea
# 651       22-Jul-2013  2013.0    Unprovoked       BRAZIL       Pernambuco
#
#                             Location      Activity Sex   Age  \
# 4425                           Beira      Swimming    M  NaN
# 1174                      Hawkes Bay       Fishing  NaN  NaN
# 4849                       Galveston      Swimming    M   14
# 3404  A few miles south of Port Suez  Air disaster    M  NaN
# 651         Boa Viagem Beach, Recife      Swimming    F   18
#
#                                                  Injury Fatal (Y/N)   Time  \
# ...
